# %% [raw]
# ---
# title: "Regression Lab Practice"
# author: "Pin Kuntha"
# format:
#   revealjs:
#     theme: simple
#     toc: true
#     toc-depth: 2
# execute: true
# ---

# %% [markdown]
# # Lectures

# %% [markdown]
# ## Objectives
# - Understand regression concepts
# - Visualize regression results
# - Evaluate model performance

# %% [markdown]
# ## Introduction to Regression
#
# **Definition:** Regression predicts a continuous target variable.
#
# **Examples:**
# - Predicting house prices
# - Estimating student grades based on study time
#
# **Types:**
# - Simple Linear Regression (one input feature)
# - Multiple Linear Regression (multiple input features)

# %% [markdown]
# ## Simple Linear Regression
#
# \[
# y = \beta_0 + \beta_1 x + \epsilon
# \]

# %% [markdown]
# ## Multiple Linear Regression
#
# \[
# y = \beta_0 + \beta_1 x_1 + \beta_2 x_2 + \dots + \beta_n x_n + \epsilon
# \]

# %% [markdown]
# # Lab Practice

# %% [markdown]
# ## Simple Linear Regression Demo

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample data
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 4, 5, 4, 5])

# Fit model
model = LinearRegression().fit(x, y)
y_pred = model.predict(x)

# Plot
plt.scatter(x, y, label="Data")
plt.plot(x, y_pred, color="red", label="Regression line")
plt.legend()
plt.show()

# %% [markdown]
# ## Multiple Linear Regression Demo

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Sample dataset
data = {
    "area": [1400, 1600, 1700, 1875, 1100],
    "bedrooms": [3, 3, 4, 3, 2],
    "age": [20, 15, 18, 10, 30],
    "price": [245000, 312000, 279000, 308000, 199000]
}
df = pd.DataFrame(data)

X = df[["area", "bedrooms", "age"]]
y = df["price"]

# Fit model
model = LinearRegression().fit(X, y)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [  -15.83104825  7091.64381585 -6276.27844326]
# Intercept: 388364.50666278205

# %% [markdown]
# ## Model Evaluation

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(X)
print("MSE:", mean_squared_error(y, y_pred))
print("R^2 Score:", r2_score(y, y_pred))
# Out:
# MSE: 171572540.5301389
# R^2 Score: 0.9040979852154569
